# %%
import numpy as np
x_train=np.load('../../datasets/eyaleb/d_eyaleb.npy')
x_train=x_train.reshape(x_train.shape[0]*x_train.shape[1],784)
y=np.load('../../datasets/eyaleb/eyalebpredictions.npy')

# %%
from sklearn.manifold import TSNE
# %matplotlib inline
import matplotlib.pyplot as plt
# %pylab inline
import seaborn as sns

figure(figsize=(10, 6))
subplot(121)

X_tsne = TSNE(n_components=2,  verbose=1, random_state=123).fit_transform(x_train)

ax=sns.scatterplot(x=X_tsne[:,0], y=X_tsne[:,1], hue=y.tolist(), marker='.',s=8,
                palette=sns.color_palette("hls", 38),
                data=x_train,legend = False)
ax.axis('off')
#plt.savefig('SDSCeyalebc38.pdf')
# Out:
# Populating the interactive namespace from numpy and matplotlib
# [t-SNE] Computing 91 nearest neighbors...
# [t-SNE] Indexed 2430 samples in 0.002s...
# [t-SNE] Computed neighbors for 2430 samples in 0.418s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 2430
# [t-SNE] Computed conditional probabilities for sample 2000 / 2430
# [t-SNE] Computed conditional probabilities for sample 2430 / 2430
# [t-SNE] Mean sigma: 0.442887
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 51.883080
# [t-SNE] KL divergence after 1000 iterations: 0.250183

# %%
from sklearn.manifold import TSNE
# %matplotlib inline
import matplotlib.pyplot as plt
# %pylab inline
import seaborn as sns

y_ids = range(len(y))
X_tsne = TSNE(n_components=2,  verbose=1, random_state=123).fit_transform(x_train)
figure(figsize=(6, 3))
subplot(121)
colors = 'lightgreen','g', 'b', 'k', 'pink', 'purple', 'gray', 'red','c','y'

for i, c, label in  zip(y_ids,colors,np.unique(y)):
    plt.scatter(X_tsne[y == i, 0], X_tsne[y == i, 1], label=label,c=c, marker='.',s=8)
    plt.axis('off')
#plt.savefig('SDSCeyalebc10.pdf')
# Out:
# Populating the interactive namespace from numpy and matplotlib
# [t-SNE] Computing 91 nearest neighbors...
# [t-SNE] Indexed 2430 samples in 0.001s...
# [t-SNE] Computed neighbors for 2430 samples in 0.734s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 2430
# [t-SNE] Computed conditional probabilities for sample 2000 / 2430
# [t-SNE] Computed conditional probabilities for sample 2430 / 2430
# [t-SNE] Mean sigma: 0.442887
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 51.883080
# [t-SNE] KL divergence after 1000 iterations: 0.250183

# %%
x_train=np.load('/media/itu-cvl/New Volume/DSE paper/literature/SeNet/datasets/coil100/dcoil100fromsenet.npy')
x_train=x_train.reshape(x_train.shape[0]*x_train.shape[1],3000)
y=np.load('../../datasets/coil100/all/sdsccoil100predictions.npy')

# %%
x=np.array(x_train)
y=np.array(y)
xtr=[]
ytr=[]
for i in range(len(y)):
    if y[i]==10:
        xtr.append(x[i])
        ytr.append(y[i])
    elif y[i]==1:
        xtr.append(x[i])
        ytr.append(y[i])
    elif y[i]==2:
        xtr.append(x[i])
        ytr.append(y[i])
    elif y[i]==3:
        xtr.append(x[i])
        ytr.append(y[i])
    elif y[i]==4:
        xtr.append(x[i])
        ytr.append(y[i])
    elif y[i]==5:
        xtr.append(x[i])
        ytr.append(y[i])
    elif y[i]==6:
        xtr.append(x[i])
        ytr.append(y[i])
    elif y[i]==7:
        xtr.append(x[i])
        ytr.append(y[i])
    elif y[i]==8:
        xtr.append(x[i])
        ytr.append(y[i])
    elif y[i]==9:
        xtr.append(x[i])
        ytr.append(y[i])
    else:
        continue
x_train=xtr
y=ytr

x=np.array(x)
y=np.array(y)
y=y-1
y=y.reshape(len(y),)

y_ids = range(len(y))
X_tsne = TSNE(n_components=2,  verbose=1, random_state=123).fit_transform(x_train)
figure(figsize=(6, 3))
subplot(121)
colors = 'lightgreen','g', 'b', 'k', 'pink', 'purple', 'gray', 'red','c','y'

for i, c, label in  zip(y_ids,colors,np.unique(y)):
    plt.scatter(X_tsne[y == i, 0], X_tsne[y == i, 1], label=label,c=c, marker='.',s=8)
    plt.axis('off')
#plt.savefig('SDSCcoil100c10.pdf')
# Out:
# [t-SNE] Computing 91 nearest neighbors...
# [t-SNE] Indexed 777 samples in 0.002s...
# [t-SNE] Computed neighbors for 777 samples in 0.334s...
# [t-SNE] Computed conditional probabilities for sample 777 / 777
# [t-SNE] Mean sigma: 0.348004
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 45.969898
# [t-SNE] KL divergence after 1000 iterations: 0.152424

# %%
from sklearn.manifold import TSNE
# %matplotlib inline
import matplotlib.pyplot as plt
# %pylab inline
import seaborn as sns

figure(figsize=(10, 6))
subplot(121)

X_tsne = TSNE(n_components=2,  verbose=1, random_state=123).fit_transform(x_train)

ax=sns.scatterplot(x=X_tsne[:,0], y=X_tsne[:,1], hue=y.tolist(),marker='.',s=8,
                palette=sns.color_palette("hls", 100),
                data=x_train,legend = False)
ax.axis('off')
#plt.savefig('SDSCcoil100c100.pdf')
# Out:
# Populating the interactive namespace from numpy and matplotlib
# [t-SNE] Computing 91 nearest neighbors...
# [t-SNE] Indexed 7200 samples in 0.018s...
# [t-SNE] Computed neighbors for 7200 samples in 4.775s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 7200
# [t-SNE] Computed conditional probabilities for sample 2000 / 7200
# [t-SNE] Computed conditional probabilities for sample 3000 / 7200
# [t-SNE] Computed conditional probabilities for sample 4000 / 7200
# [t-SNE] Computed conditional probabilities for sample 5000 / 7200
# [t-SNE] Computed conditional probabilities for sample 6000 / 7200
# [t-SNE] Computed conditional probabilities for sample 7000 / 7200
# [t-SNE] Computed conditional probabilities for sample 7200 / 7200
# [t-SNE] Mean sigma: 0.334183
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 61.074802
# [t-SNE] KL divergence after 1000 iterations: 0.418522

# %%
import numpy as np
x_train=np.load('/media/itu-cvl/New Volume/DSE paper/literature/SeNet/datasets/MNIST/dmnist70kfromsenet.npy')
x_train=x_train.reshape(x_train.shape[0]*x_train.shape[1],2000)
y=np.load('../../datasets/mnistpca2000/all/sdscmnistpredictions.npy')

# %%
x_train=x_train[57000:60000,:]
y=y[57000:60000,]
from sklearn.manifold import TSNE
# %matplotlib inline
import matplotlib.pyplot as plt
# %pylab inline
import seaborn as sns

y_ids = range(len(y))
X_tsne = TSNE(n_components=2,  verbose=1, random_state=123).fit_transform(x_train)
figure(figsize=(6, 3))
subplot(121)
colors = 'lightgreen','g', 'b', 'k', 'pink', 'purple', 'gray', 'red','c','y'

for i, c, label in  zip(y_ids,colors,np.unique(y)):
    plt.scatter(X_tsne[y == i, 0], X_tsne[y == i, 1], label=label,c=c, marker='.',s=8)
    plt.axis('off')
#plt.savefig('SDSCmnistc10.pdf')
# Out:
# Populating the interactive namespace from numpy and matplotlib
# [t-SNE] Computing 91 nearest neighbors...
# [t-SNE] Indexed 3000 samples in 0.003s...
# [t-SNE] Computed neighbors for 3000 samples in 0.507s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 3000
# [t-SNE] Computed conditional probabilities for sample 2000 / 3000
# [t-SNE] Computed conditional probabilities for sample 3000 / 3000
# [t-SNE] Mean sigma: 0.301594
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 70.007797
# [t-SNE] KL divergence after 1000 iterations: 1.022123

# %%
x_train=np.load('/media/itu-cvl/New Volume/DSE paper/literature/SeNet/datasets/ORL/sdscdorlfullfromsenet.npy')
x_train=x_train.reshape(x_train.shape[0]*x_train.shape[1],400)
y=np.load('../../datasets/orl/all/sdscorlpredictions.npy')

# %%
from sklearn.manifold import TSNE
# %matplotlib inline
import matplotlib.pyplot as plt
# %pylab inline
import seaborn as sns

figure(figsize=(10, 6))
subplot(121)

X_tsne = TSNE(n_components=2,  verbose=1, random_state=123).fit_transform(x_train)

ax=sns.scatterplot(x=X_tsne[:,0], y=X_tsne[:,1], hue=y.tolist(),
                palette=sns.color_palette("hls", 40),
                data=x_train,legend = False)
ax.axis('off')
#plt.savefig('SDSCorlc40.pdf')
# Out:
# Populating the interactive namespace from numpy and matplotlib
# [t-SNE] Computing 91 nearest neighbors...
# [t-SNE] Indexed 400 samples in 0.000s...
# [t-SNE] Computed neighbors for 400 samples in 0.031s...
# [t-SNE] Computed conditional probabilities for sample 400 / 400
# [t-SNE] Mean sigma: 0.504892
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 66.557846
# [t-SNE] KL divergence after 1000 iterations: 0.494708
# (-31.14148540496826,
#  32.857618522644046,
#  -32.46723165512085,
#  30.239278697967528)

# %%
from sklearn.manifold import TSNE
# %matplotlib inline
import matplotlib.pyplot as plt
# %pylab inline
import seaborn as sns

y_ids = range(len(y))
X_tsne = TSNE(n_components=2,  verbose=1, random_state=123).fit_transform(x_train)
figure(figsize=(6, 3))
subplot(121)
colors = 'lightgreen','g', 'b', 'k', 'pink', 'purple', 'gray', 'red','c','y'

for i, c, label in  zip(y_ids,colors,np.unique(y)):
    plt.scatter(X_tsne[y == i, 0], X_tsne[y == i, 1], label=label,c=c, marker='.',s=8)
    plt.axis('off')
#plt.savefig('SDSCorlc10.pdf')
# Out:
# Populating the interactive namespace from numpy and matplotlib
# [t-SNE] Computing 91 nearest neighbors...
# [t-SNE] Indexed 400 samples in 0.000s...
# [t-SNE] Computed neighbors for 400 samples in 0.035s...
# [t-SNE] Computed conditional probabilities for sample 400 / 400
# [t-SNE] Mean sigma: 0.504892
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 66.557846
# [t-SNE] KL divergence after 1000 iterations: 0.494708

# %%
display first 10 of my ...then all clusters of my and all clusters of sota,,,
or display all clusters of my... then 10 clusters of sota and 10 clusters of my...
whatevre setting is visually appealing 
github arrange, upload, send login info
